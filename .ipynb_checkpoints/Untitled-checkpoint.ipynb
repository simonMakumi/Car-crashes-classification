# %% [markdown]
# #            Car Accident Contributory Cause Classification in Chicago
#
# ![CPD image](CPD.jpg)
#
# ## Introduction
#
# Car accidents are a significant public safety issue, and understanding the causes behind them is crucial for implementing effective prevention strategies. This project aims to build a classifier that predicts the primary contributory cause of car accidents in Chicago using data on the people involved, the vehicles, and the crash conditions. The insights gained from this model can help the Vehicle Safety Board and the City of Chicago identify key factors contributing to accidents and take preventive measures to enhance road safety.
#
# ## Business Understanding
#
# ### Overview
# The primary goal of this project is to build a classifier that predicts the primary contributory cause of car accidents in Chicago. The target audience includes the Vehicle Safety Board and the City of Chicago, who are interested in reducing traffic accidents and uncovering patterns that lead to accidents.
#
# ### Challenges
# 1. **Data Complexity**: The datasets include a wide range of information about people, vehicles, and accidents, which makes data cleaning and preprocessing challenging.
# 2. **Class Imbalance**: Some primary contributory causes have very few samples, leading to potential class imbalance issues.
# 3. **Feature Engineering**: Identifying the most relevant features from a large number of variables requires careful analysis and domain knowledge.
#
# ### Proposed Solution
# - **Metrics**: The primary metric for evaluating the model will be the accuracy score, with a target accuracy of 80%.
# - **Other Metrics**: We will also consider precision, recall, and F1 score to get a comprehensive understanding of model performance.
#
# ### Brief Conclusion
# By building a reliable classifier, we can help the City of Chicago and the Vehicle Safety Board identify key factors contributing to car accidents and take preventive measures to enhance road safety.
#
# ### Problem Statement
# The goal of this project is to develop a classification model that predicts the primary contributory cause of car accidents in Chicago using data about the people involved, the vehicles, and the crash conditions. This model will help stakeholders understand the factors leading to accidents and implement measures to reduce their occurrence.
#
# ### Objectives
# 1. **Data Collection**: Gather and combine datasets related to traffic crashes, people involved, and vehicles.
# 2. **Data Cleaning and Preparation**: Handle missing values, duplicates, and outliers. Perform necessary data transformations.
# 3. **Exploratory Data Analysis (EDA)**: Conduct univariate and bivariate analysis to understand the data distribution and relationships.
# 4. **Modeling**: Build and evaluate multiple classification models, starting with a baseline model and progressing to more complex models.
# 5. **Evaluation**: Assess model performance using metrics such as accuracy, precision, recall, and F1 score.
# 6. **Recommendations**: Provide actionable insights and recommendations based on the model's findings.

# %% [markdown]
# ## Data Understanding
#
# ### Sources
# The datasets used in this project are:
# 1. **People Dataset**: Information about people involved in crashes.
# 2. **Vehicle Dataset**: Information about vehicles involved in crashes.
#
# Both datasets are available for download from the Chicago Data Portal.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
# Load the People dataset in chunks to avoid errors when loading due to data size.
chunk_size = 50000
chunks = pd.read_csv('Traffic_Crashes_-_People_20240531.csv', chunksize=chunk_size)

# Initialize an empty list to store the chunks
people_chunks = []

# Iterate over the chunks and append them to the list
for chunk in chunks:
    people_chunks.append(chunk)

# Concatenate the chunks to create the full People dataset
people_data = pd.concat(people_chunks, ignore_index=True)

# Display the first few rows of the People dataset
people_data.head()
# Out:
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0   O749947      DRIVER  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...
# 1   O871921      DRIVER  af84fb5c8d996fcd3aefd36593c3a02e6e7509eeb27568...
# 2    O10018      DRIVER  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# 3    O10038      DRIVER  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# 4    O10039      DRIVER  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
#
#    VEHICLE_ID              CRASH_DATE  SEAT_NO     CITY STATE ZIPCODE SEX  \
# 0    834816.0  09/28/2019 03:30:00 AM      NaN  CHICAGO    IL   60651   M
# 1    827212.0  04/13/2020 10:50:00 PM      NaN  CHICAGO    IL   60620   M
# 2      9579.0  11/01/2015 05:00:00 AM      NaN      NaN   NaN     NaN   X
# 3      9598.0  11/01/2015 08:00:00 AM      NaN      NaN   NaN     NaN   X
# 4      9600.0  11/01/2015 10:15:00 AM      NaN      NaN   NaN     NaN   X
#
#    ...  EMS_RUN_NO     DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION  \
# 0  ...         NaN           UNKNOWN       UNKNOWN            UNKNOWN
# 1  ...         NaN              NONE  NOT OBSCURED             NORMAL
# 2  ...         NaN  IMPROPER BACKING       UNKNOWN            UNKNOWN
# 3  ...         NaN           UNKNOWN       UNKNOWN            UNKNOWN
# 4  ...         NaN           UNKNOWN       UNKNOWN            UNKNOWN
#
#   PEDPEDAL_ACTION PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT  \
# 0             NaN                 NaN               NaN  TEST NOT OFFERED
# 1             NaN                 NaN               NaN  TEST NOT OFFERED
# 2             NaN                 NaN               NaN  TEST NOT OFFERED
# 3             NaN                 NaN               NaN  TEST NOT OFFERED
# 4             NaN                 NaN               NaN  TEST NOT OFFERED
#
#   BAC_RESULT VALUE CELL_PHONE_USE
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4              NaN            NaN
#
# [5 rows x 29 columns]

# %%
# Loading the vehicle dataset and display.
vehicle_data = pd.read_csv('Traffic_Crashes_-_Vehicles_20240531.csv')
vehicle_data.head()
# Out:
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (0,20,39,40,41,43,47,48,49,52,54,57,58,60) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   CRASH_UNIT_ID                                    CRASH_RECORD_ID  \
# 0       1727162  f5943b05f46b8d4148a63b7506a59113eae0cf1075aabc...
# 1       1717556  7b1763088507f77e0e552c009a6bf89a4d6330c7527706...
# 2       1717574  2603ff5a88f0b9b54576934c5ed4e4a64e8278e005687b...
# 3       1717579  a52ef70e33d468b855b5be44e8638a564434dcf99c0edf...
# 4       1720118  609055f4b1a72a44d6ec40ba9036cefd7c1287a755eb6c...
#
#                CRASH_DATE  UNIT_NO   UNIT_TYPE  NUM_PASSENGERS  VEHICLE_ID  \
# 0  12/21/2023 08:57:00 AM      2.0  PEDESTRIAN             NaN         NaN
# 1  12/06/2023 03:24:00 PM      1.0      DRIVER             NaN   1634931.0
# 2  12/06/2023 04:00:00 PM      2.0      DRIVER             NaN   1634978.0
# 3  12/06/2023 04:30:00 PM      1.0      DRIVER             NaN   1634948.0
# 4  12/10/2023 12:12:00 PM      1.0      DRIVER             NaN   1637401.0
#
#   CMRC_VEH_I      MAKE    MODEL  ... TRAILER1_LENGTH  TRAILER2_LENGTH  \
# 0        NaN       NaN      NaN  ...             NaN              NaN
# 1        NaN    NISSAN   SENTRA  ...             NaN              NaN
# 2        NaN  CHRYSLER  SEBRING  ...             NaN              NaN
# 3        NaN    SUBARU  OUTBACK  ...             NaN              NaN
# 4        NaN    TOYOTA     RAV4  ...             NaN              NaN
#
#   TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE  \
# 0                  NaN      NaN            NaN             NaN       NaN
# 1                  NaN      NaN            NaN             NaN       NaN
# 2                  NaN      NaN            NaN             NaN       NaN
# 3                  NaN      NaN            NaN             NaN       NaN
# 4                  NaN      NaN            NaN             NaN       NaN
#
#   HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  HAZMAT_CLASS
# 0                     NaN                  NaN           NaN
# 1                     NaN                  NaN           NaN
# 2                     NaN                  NaN           NaN
# 3                     NaN                  NaN           NaN
# 4                     NaN                  NaN           NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# ## Data Preparation
#
# In this section, we merge the People and Vehicle datasets based on the `CRASH_RECORD_ID` column. This will allow us to combine information about people involved in crashes with information about the vehicles involved.

# %%
# Merge the People and Vehicle datasets based on CRASH_RECORD_ID
df = pd.merge(people_data, vehicle_data, on='CRASH_RECORD_ID', how='inner')

# Display the first few rows of the merged dataset
df.head()
# Out:
#   PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0    O10018      DRIVER  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# 1    O10018      DRIVER  71162af7bf22799b776547132ebf134b5b438dcf3dac6b...
# 2    O10038      DRIVER  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# 3    O10038      DRIVER  c21c476e2ccc41af550b5d858d22aaac4ffc88745a1700...
# 4    O10039      DRIVER  eb390a4c8e114c69488f5fb8a097fe629f5a92fd528cf4...
#
#    VEHICLE_ID_x            CRASH_DATE_x  SEAT_NO CITY STATE ZIPCODE SEX  ...  \
# 0        9579.0  11/01/2015 05:00:00 AM      NaN  NaN   NaN     NaN   X  ...
# 1        9579.0  11/01/2015 05:00:00 AM      NaN  NaN   NaN     NaN   X  ...
# 2        9598.0  11/01/2015 08:00:00 AM      NaN  NaN   NaN     NaN   X  ...
# 3        9598.0  11/01/2015 08:00:00 AM      NaN  NaN   NaN     NaN   X  ...
# 4        9600.0  11/01/2015 10:15:00 AM      NaN  NaN   NaN     NaN   X  ...
#
#    TRAILER1_LENGTH TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH AXLE_CNT  \
# 0              NaN             NaN                  NaN      NaN
# 1              NaN             NaN                  NaN      NaN
# 2              NaN             NaN                  NaN      NaN
# 3              NaN             NaN                  NaN      NaN
# 4              NaN             NaN                  NaN      NaN
#
#   VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I  \
# 0            NaN             NaN       NaN                     NaN
# 1            NaN             NaN       NaN                     NaN
# 2            NaN             NaN       NaN                     NaN
# 3            NaN             NaN       NaN                     NaN
# 4            NaN             NaN       NaN                     NaN
#
#   MCS_OUT_OF_SERVICE_I HAZMAT_CLASS
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN
#
# [5 rows x 99 columns]

# %%
df.columns
# Out:
# Index(['PERSON_ID', 'PERSON_TYPE', 'CRASH_RECORD_ID', 'VEHICLE_ID_x',
#        'CRASH_DATE_x', 'SEAT_NO', 'CITY', 'STATE', 'ZIPCODE', 'SEX', 'AGE',
#        'DRIVERS_LICENSE_STATE', 'DRIVERS_LICENSE_CLASS', 'SAFETY_EQUIPMENT',
#        'AIRBAG_DEPLOYED', 'EJECTION', 'INJURY_CLASSIFICATION', 'HOSPITAL',
#        'EMS_AGENCY', 'EMS_RUN_NO', 'DRIVER_ACTION', 'DRIVER_VISION',
#        'PHYSICAL_CONDITION', 'PEDPEDAL_ACTION', 'PEDPEDAL_VISIBILITY',
#        'PEDPEDAL_LOCATION', 'BAC_RESULT', 'BAC_RESULT VALUE', 'CELL_PHONE_USE',
#        'CRASH_UNIT_ID', 'CRASH_DATE_y', 'UNIT_NO', 'UNIT_TYPE',
#        'NUM_PASSENGERS', 'VEHICLE_ID_y', 'CMRC_VEH_I', 'MAKE', 'MODEL',
#        'LIC_PLATE_STATE', 'VEHICLE_YEAR', 'VEHICLE_DEFECT', 'VEHICLE_TYPE',
#        'VEHICLE_USE', 'TRAVEL_DIRECTION', 'MANEUVER', 'TOWED_I', 'FIRE_I',
#        'OCCUPANT_CNT', 'EXCEED_SPEED_LIMIT_I', 'TOWED_BY', 'TOWED_TO',
#        'AREA_00_I', 'AREA_01_I', 'AREA_02_I', 'AREA_03_I', 'AREA_04_I',
#        'AREA_05_I', 'AREA_06_I', 'AREA_07_I', 'AREA_08_I', 'AREA_09_I',
#        'AREA_10_I', 'AREA_11_I', 'AREA_12_I', 'AREA_99_I',
#        'FIRST_CONTACT_POINT', 'CMV_ID', 'USDOT_NO', 'CCMC_NO', 'ILCC_NO',
#        'COMMERCIAL_SRC', 'GVWR', 'CARRIER_NAME', 'CARRIER_STATE',
#        'CARRIER_CITY', 'HAZMAT_PLACARDS_I', 'HAZMAT_NAME', 'UN_NO',
#        'HAZMAT_PRESENT_I', 'HAZMAT_REPORT_I', 'HAZMAT_REPORT_NO',
#        'MCS_REPORT_I', 'MCS_REPORT_NO', 'HAZMAT_VIO_CAUSE_CRASH_I',
#        'MCS_VIO_CAUSE_CRASH_I', 'IDOT_PERMIT_NO', 'WIDE_LOAD_I',
#        'TRAILER1_WIDTH', 'TRAILER2_WIDTH', 'TRAILER1_LENGTH',
#        'TRAILER2_LENGTH', 'TOTAL_VEHICLE_LENGTH', 'AXLE_CNT', 'VEHICLE_CONFIG',
#        'CARGO_BODY_TYPE', 'LOAD_TYPE', 'HAZMAT_OUT_OF_SERVICE_I',
#        'MCS_OUT_OF_SERVICE_I', 'HAZMAT_CLASS'],
#       dtype='object')

# %%
relevant_columns = ['PERSON_TYPE', 'SEX', 'AGE', 'SAFETY_EQUIPMENT','AIRBAG_DEPLOYED', 'EJECTION', 'INJURY_CLASSIFICATION',
                    'DRIVER_ACTION', 'DRIVER_VISION', 'PHYSICAL_CONDITION', 'BAC_RESULT VALUE', 'CELL_PHONE_USE',
                    'NUM_PASSENGERS', 'MAKE', 'MODEL', 'VEHICLE_YEAR', 'VEHICLE_DEFECT','VEHICLE_USE', 'CRASH_DATE_x']
df = df[relevant_columns]
df.head()
# Out:
#   PERSON_TYPE SEX  AGE SAFETY_EQUIPMENT     AIRBAG_DEPLOYED EJECTION  \
# 0      DRIVER   X  NaN    USAGE UNKNOWN  DEPLOYMENT UNKNOWN     NONE
# 1      DRIVER   X  NaN    USAGE UNKNOWN  DEPLOYMENT UNKNOWN     NONE
# 2      DRIVER   X  NaN    USAGE UNKNOWN  DEPLOYMENT UNKNOWN  UNKNOWN
# 3      DRIVER   X  NaN    USAGE UNKNOWN  DEPLOYMENT UNKNOWN  UNKNOWN
# 4      DRIVER   X  NaN    USAGE UNKNOWN  DEPLOYMENT UNKNOWN  UNKNOWN
#
#      INJURY_CLASSIFICATION     DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION  \
# 0  NO INDICATION OF INJURY  IMPROPER BACKING       UNKNOWN            UNKNOWN
# 1  NO INDICATION OF INJURY  IMPROPER BACKING       UNKNOWN            UNKNOWN
# 2  NO INDICATION OF INJURY           UNKNOWN       UNKNOWN            UNKNOWN
# 3  NO INDICATION OF INJURY           UNKNOWN       UNKNOWN            UNKNOWN
# 4  NO INDICATION OF INJURY           UNKNOWN       UNKNOWN            UNKNOWN
#
#    BAC_RESULT VALUE CELL_PHONE_USE  NUM_PASSENGERS     MAKE          MODEL  \
# 0               NaN            NaN             NaN  UNKNOWN        UNKNOWN
# 1               NaN            NaN             NaN    ACURA          ACURA
# 2               NaN            NaN             NaN    DODGE  GRAND CARAVAN
# 3               NaN            NaN             NaN  UNKNOWN        UNKNOWN
# 4               NaN            NaN             NaN  UNKNOWN        UNKNOWN
#
#    VEHICLE_YEAR VEHICLE_DEFECT VEHICLE_USE            CRASH_DATE_x
# 0           NaN           NONE    PERSONAL  11/01/2015 05:00:00 AM
# 1        2005.0           NONE    PERSONAL  11/01/2015 05:00:00 AM
# 2        2012.0           NONE  NOT IN USE  11/01/2015 08:00:00 AM
# 3           NaN        UNKNOWN  UNKNOWN/NA  11/01/2015 08:00:00 AM
# 4           NaN        UNKNOWN  UNKNOWN/NA  11/01/2015 10:15:00 AM

# %%
df.shape
# Out:
# (933599, 19)

# %% [markdown]
# ### Data Reduction
# To handle the large dataset size, we sampled 30% of the data from each year using the `CRASH_DATE_x` column. This reduced the dataset to a manageable size while preserving yearly representation.

# %%
# Convert CRASH_DATE_x to datetime
df['CRASH_DATE_x'] = pd.to_datetime(df['CRASH_DATE_x'])

# Add a year column
df['CRASH_YEAR'] = df['CRASH_DATE_x'].dt.year

# Add a month column
df['CRASH_MONTH'] = df['CRASH_DATE_x'].dt.month

# Drop CRASH_DATE_x column
df = df.drop(columns='CRASH_DATE_x')

# Sample 30% of data for each year
df = df.groupby('CRASH_YEAR').sample(frac=0.3, random_state=42).reset_index(drop=True)
display(df.shape)
df
# Out:
# (280081, 20)
#        PERSON_TYPE SEX   AGE  SAFETY_EQUIPMENT     AIRBAG_DEPLOYED EJECTION  \
# 0       PEDESTRIAN   M   3.0      NONE PRESENT                 NaN      NaN
# 1           DRIVER   X   NaN     USAGE UNKNOWN  DEPLOYMENT UNKNOWN  UNKNOWN
# 2        PASSENGER   F  14.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# 3           DRIVER   F  27.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# 4           DRIVER   F  43.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# ...            ...  ..   ...               ...                 ...      ...
# 280076      DRIVER   F   NaN     USAGE UNKNOWN  DEPLOYMENT UNKNOWN     NONE
# 280077      DRIVER   M  63.0     USAGE UNKNOWN      DEPLOYED, SIDE     NONE
# 280078      DRIVER   F  37.0  SAFETY BELT USED  DEPLOYMENT UNKNOWN     NONE
# 280079      DRIVER   M  31.0  SAFETY BELT USED      NOT APPLICABLE     NONE
# 280080      DRIVER   F  33.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
#
#            INJURY_CLASSIFICATION     DRIVER_ACTION DRIVER_VISION  \
# 0       NONINCAPACITATING INJURY           UNKNOWN       UNKNOWN
# 1        NO INDICATION OF INJURY           UNKNOWN       UNKNOWN
# 2        NO INDICATION OF INJURY               NaN           NaN
# 3        NO INDICATION OF INJURY              NONE  NOT OBSCURED
# 4        NO INDICATION OF INJURY             OTHER  NOT OBSCURED
# ...                          ...               ...           ...
# 280076   NO INDICATION OF INJURY  IMPROPER BACKING       UNKNOWN
# 280077     REPORTED, NOT EVIDENT              NONE       UNKNOWN
# 280078   NO INDICATION OF INJURY              NONE       UNKNOWN
# 280079   NO INDICATION OF INJURY              NONE  NOT OBSCURED
# 280080   NO INDICATION OF INJURY              NONE  NOT OBSCURED
#
#        PHYSICAL_CONDITION  BAC_RESULT VALUE CELL_PHONE_USE  NUM_PASSENGERS  \
# 0                  NORMAL               NaN            NaN             NaN
# 1                 UNKNOWN               NaN            NaN             NaN
# 2                     NaN               NaN            NaN             2.0
# 3                  NORMAL               NaN            NaN             1.0
# 4                  NORMAL               NaN            NaN             NaN
# ...                   ...               ...            ...             ...
# 280076            UNKNOWN               NaN            NaN             NaN
# 280077             NORMAL               NaN            NaN             2.0
# 280078             NORMAL               NaN            NaN             NaN
# 280079             NORMAL               NaN            NaN             NaN
# 280080             NORMAL               NaN            NaN             NaN
#
#                               MAKE                         MODEL  \
# 0                            HONDA                         CIVIC
# 1       TOYOTA MOTOR COMPANY, LTD.                         CAMRY
# 2                        CHEVROLET             MALIBU (CHEVELLE)
# 3                            HONDA                           CRV
# 4                         CADILLAC                     FLEETWOOD
# ...                            ...                           ...
# 280076                   CHEVROLET                  TRAIL BLAZER
# 280077                        AUDI  OTHER (EXPLAIN IN NARRATIVE)
# 280078                   CHEVROLET                      TRAVERSE
# 280079                       HONDA                           FIT
# 280080                         KIA                          SOUL
#
#         VEHICLE_YEAR VEHICLE_DEFECT VEHICLE_USE  CRASH_YEAR  CRASH_MONTH
# 0             2010.0           NONE    PERSONAL        2013            6
# 1             2014.0         BRAKES    PERSONAL        2014           11
# 2             2011.0           NONE    PERSONAL        2015           11
# 3             2015.0           NONE    PERSONAL        2015           11
# 4             1990.0           NONE    PERSONAL        2015           11
# ...              ...            ...         ...         ...          ...
# 280076           NaN        UNKNOWN    PERSONAL        2023           12
# 280077        2007.0        UNKNOWN    PERSONAL        2023           12
# 280078        2017.0        UNKNOWN    PERSONAL        2023           12
# 280079        2007.0        UNKNOWN    PERSONAL        2023           12
# 280080        2016.0           NONE    PERSONAL        2023           12
#
# [280081 rows x 20 columns]

# %% [markdown]
# # Data Cleaning: Handling Missing Values
#
# In this step, we address missing values in the dataset. Missing values can hinder analysis and modeling efforts, so it's essential to handle them appropriately. We employ several strategies to deal with missing values, including filling with placeholders, dropping rows or columns, and imputing with statistical measures.

# %%
df.isna().sum()
# Out:
# PERSON_TYPE                   0
# SEX                        4636
# AGE                       85726
# SAFETY_EQUIPMENT            706
# AIRBAG_DEPLOYED            4692
# EJECTION                   3021
# INJURY_CLASSIFICATION        81
# DRIVER_ACTION             56360
# DRIVER_VISION             56450
# PHYSICAL_CONDITION        56204
# BAC_RESULT VALUE         279735
# CELL_PHONE_USE           280042
# NUM_PASSENGERS           211887
# MAKE                       5489
# MODEL                      5494
# VEHICLE_YEAR              44253
# VEHICLE_DEFECT             5489
# VEHICLE_USE                5489
# CRASH_YEAR                    0
# CRASH_MONTH                   0
# dtype: int64

# %% [markdown]
# ## 1. Fill Missing Values
#
# ### Fill with 'UNKNOWN'
#
# Certain columns contain categorical data where missing values can be reasonably replaced with 'UNKNOWN'. These columns include:
# - `DRIVER_ACTION`
# - `DRIVER_VISION`
# - `VEHICLE_DEFECT`
# - `VEHICLE_USE`
# - `PHYSICAL_CONDITION`
#
# ### Drop 'rows'
#
# The following rows with missing values will be dropped:
# - `SAFETY_EQUIPMENT`
# - `AIRBAG_DEPLOYED`
# - `EJECTION`
# - `INJURY_CLASSIFICATION`
# - `MAKE`
# - `MODEL`
#
# ### Drop columns with too many missing values
# The following columns will be affected:
# - `BAC_RESULT VALUE`
# - `CELL_PHONE_USE`
# - `NUM_PASSENGERS`
#
# ### Fill with median and SEX with X
# These columns will be filled with the median:
# - `AGE`
# - `VEHICLE_YEAR`
# - `SEX`

# %%
# Fill with 'UNKNOWN'
unknown_columns = ['DRIVER_ACTION', 'DRIVER_VISION', 'VEHICLE_DEFECT', 'VEHICLE_USE', 'PHYSICAL_CONDITION']
df[unknown_columns] = df[unknown_columns].fillna('UNKNOWN')

# Drop rows with missing values in these columns
drop_rows_columns = ['SAFETY_EQUIPMENT', 'AIRBAG_DEPLOYED', 'EJECTION', 'INJURY_CLASSIFICATION', 'MAKE', 'MODEL']
df.dropna(subset=drop_rows_columns, inplace=True)

# Drop columns with too many missing values
drop_columns = ['BAC_RESULT VALUE', 'CELL_PHONE_USE', 'NUM_PASSENGERS']
df.drop(columns=drop_columns, inplace=True)

# Fill with median
df['AGE'].fillna(df['AGE'].median(), inplace=True)
df['SEX'].fillna('X', inplace=True)
df['VEHICLE_YEAR'].fillna(df['VEHICLE_YEAR'].median(), inplace=True)

# Check the dataset after handling missing values
print(df.isnull().sum())

# Display the first few rows of the cleaned dataset
df.head()
# Out:
# PERSON_TYPE              0
# SEX                      0
# AGE                      0
# SAFETY_EQUIPMENT         0
# AIRBAG_DEPLOYED          0
# EJECTION                 0
# INJURY_CLASSIFICATION    0
# DRIVER_ACTION            0
# DRIVER_VISION            0
# PHYSICAL_CONDITION       0
# MAKE                     0
# MODEL                    0
# VEHICLE_YEAR             0
# VEHICLE_DEFECT           0
# VEHICLE_USE              0
# CRASH_YEAR               0
# CRASH_MONTH              0
# dtype: int64
#   PERSON_TYPE SEX   AGE  SAFETY_EQUIPMENT     AIRBAG_DEPLOYED EJECTION  \
# 1      DRIVER   X  35.0     USAGE UNKNOWN  DEPLOYMENT UNKNOWN  UNKNOWN
# 2   PASSENGER   F  14.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# 3      DRIVER   F  27.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# 4      DRIVER   F  43.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
# 5      DRIVER   F  26.0  SAFETY BELT USED      DID NOT DEPLOY     NONE
#
#      INJURY_CLASSIFICATION DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION  \
# 1  NO INDICATION OF INJURY       UNKNOWN       UNKNOWN            UNKNOWN
# 2  NO INDICATION OF INJURY       UNKNOWN       UNKNOWN            UNKNOWN
# 3  NO INDICATION OF INJURY          NONE  NOT OBSCURED             NORMAL
# 4  NO INDICATION OF INJURY         OTHER  NOT OBSCURED             NORMAL
# 5  NO INDICATION OF INJURY          NONE  NOT OBSCURED             NORMAL
#
#                          MAKE              MODEL  VEHICLE_YEAR VEHICLE_DEFECT  \
# 1  TOYOTA MOTOR COMPANY, LTD.              CAMRY        2014.0         BRAKES
# 2                   CHEVROLET  MALIBU (CHEVELLE)        2011.0           NONE
# 3                       HONDA                CRV        2015.0           NONE
# 4                    CADILLAC          FLEETWOOD        1990.0           NONE
# 5  TOYOTA MOTOR COMPANY, LTD.            COROLLA        1997.0        UNKNOWN
#
#   VEHICLE_USE  CRASH_YEAR  CRASH_MONTH
# 1    PERSONAL        2014           11
# 2    PERSONAL        2015           11
# 3    PERSONAL        2015           11
# 4    PERSONAL        2015           11
# 5  UNKNOWN/NA        2015            9

# %%
df['VEHICLE_YEAR'].value_counts()
# Out:
# 2013.0    51403
# 2017.0    16502
# 2015.0    16292
# 2016.0    15600
# 2014.0    14235
#           ...
# 2929.0        1
# 3017.0        1
# 3022.0        1
# 3029.0        1
# 2049.0        1
# Name: VEHICLE_YEAR, Length: 108, dtype: int64

# %%
# Ensure 'VEHICLE_YEAR' is treated as an integer
df['VEHICLE_YEAR'] = df['VEHICLE_YEAR'].astype('Int64')

# Filter out rows where 'VEHICLE_YEAR' is before 1900 or after 2024
df = df[(df['VEHICLE_YEAR'] >= 1900) & (df['VEHICLE_YEAR'] <= 2024) | (df['VEHICLE_YEAR'].isna())]

df['VEHICLE_YEAR'].describe()
# Out:
# count    272063.000000
# mean       2012.246906
# std           5.961582
# min        1900.000000
# 25%        2009.000000
# 50%        2013.000000
# 75%        2016.000000
# max        2023.000000
# Name: VEHICLE_YEAR, dtype: float64

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Overview
#
# In this section, we will explore the dataset to gain insights and understand its characteristics. This exploration will help us understand the data better and make informed decisions during the modeling phase.

# %%
df.describe()
# Out:
#                  AGE   VEHICLE_YEAR     CRASH_YEAR    CRASH_MONTH
# count  272063.000000  272063.000000  272063.000000  272063.000000
# mean       36.734727    2012.246906    2020.830679       6.135134
# std        14.205662       5.961582       1.568178       3.463980
# min        -1.000000    1900.000000    2014.000000       1.000000
# 25%        29.000000    2009.000000    2021.000000       3.000000
# 50%        35.000000    2013.000000    2021.000000       6.000000
# 75%        42.000000    2016.000000    2022.000000       9.000000
# max       110.000000    2023.000000    2023.000000      12.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 272063 entries, 1 to 280080
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   PERSON_TYPE            272063 non-null  object
#  1   SEX                    272063 non-null  object
#  2   AGE                    272063 non-null  float64
#  3   SAFETY_EQUIPMENT       272063 non-null  object
#  4   AIRBAG_DEPLOYED        272063 non-null  object
#  5   EJECTION               272063 non-null  object
#  6   INJURY_CLASSIFICATION  272063 non-null  object
#  7   DRIVER_ACTION          272063 non-null  object
#  8   DRIVER_VISION          272063 non-null  object
#  9   PHYSICAL_CONDITION     272063 non-null  object
#  10  MAKE                   272063 non-null  object
#  11  MODEL                  272063 non-null  object
#  12  VEHICLE_YEAR           272063 non-null  Int64
#  13  VEHICLE_DEFECT         272063 non-null  object
#  14  VEHICLE_USE            272063 non-null  object
#  15  CRASH_YEAR             272063 non-null  int64
#  16  CRASH_MONTH            272063 non-null  int64
# dtypes: Int64(1), float64(1), int64(2), object(13)
# memory usage: 37.6+ MB

# %%
# Histograms for AGE
plt.figure(figsize=(8, 6))
sns.histplot(df['AGE'], bins=10, kde=True)
plt.title('Distribution of AGE')
plt.xlabel('AGE')
plt.ylabel('Frequency')
plt.show()

# %%
# Histograms for CRASH_MONTH
plt.figure(figsize=(8, 6))
sns.histplot(df['CRASH_MONTH'], bins=12, kde=True)
plt.title('Distribution of CRASH_MONTH')
plt.xlabel('MONTH')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot to show correlation between Vehicle Year and CRASH_YEAR
plt.figure(figsize=(10, 6))
sns.scatterplot(x='VEHICLE_YEAR', y='CRASH_YEAR', data=df)
plt.title('Correlation between Vehicle Year and Crash Year')
plt.xlabel('Vehicle Year')
plt.ylabel('Crash Year')
plt.show()

# %% [markdown]
# ## Univariate Analysis
#
# ### Analysis of Categorical Variables
#
# In this step, we will analyze the distribution of categorical variables to understand their frequency and proportion in the dataset.

# %%
# Univariate Analysis of Categorical Variables

categorical_columns = ['PERSON_TYPE', 'SEX', 'SAFETY_EQUIPMENT', 'AIRBAG_DEPLOYED', 
                       'EJECTION', 'INJURY_CLASSIFICATION', 'DRIVER_ACTION', 'DRIVER_VISION', 
                       'PHYSICAL_CONDITION', 'VEHICLE_DEFECT', 'VEHICLE_USE']
# Calculate the number of rows needed for the subplots
n_rows = (len(categorical_columns) + 1) // 2

plt.figure(figsize=(18, n_rows * 10))  

for i, column in enumerate(categorical_columns, 1):
    plt.subplot(6, 2, i)
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis
#
# Next, we will analyze the relationships between pairs of variables. This will help us understand how different variables interact with each other.

# %%
# Bivariate Analysis: Correlation between Age and Injury Classification
plt.figure(figsize=(10, 6))
sns.boxplot(x='INJURY_CLASSIFICATION', y='AGE', data=df)
plt.title('Age vs Injury Classification')
plt.xlabel('Injury Classification')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.show()

# Bivariate Analysis: Correlation between Vehicle Use and Injury Classification
plt.figure(figsize=(10, 6))
sns.countplot(x='INJURY_CLASSIFICATION', hue='VEHICLE_USE', data=df)
plt.title('Vehicle Use vs Injury Classification')
plt.xlabel('Injury Classification')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Function to reduce categories
def reduce_categories(column, threshold=0.01):
    value_counts = column.value_counts(normalize=True)
    to_replace = value_counts[value_counts < threshold].index
    return column.replace(to_replace, 'Other')

# Apply reduction to columns with many unique categories
high_cardinality_columns = ['MAKE', 'MODEL']
for col in high_cardinality_columns:
    df[col] = reduce_categories(df[col])

# Ensure changes are applied
df[high_cardinality_columns].nunique()
# Out:
# <ipython-input-24-342c7fcfa1b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = reduce_categories(df[col])
# <ipython-input-24-342c7fcfa1b4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = reduce_categories(df[col])
# MAKE     24
# MODEL    22
# dtype: int64

# %%
# Define the categorical columns
categorical_columns = ['PERSON_TYPE', 'SEX', 'SAFETY_EQUIPMENT', 'AIRBAG_DEPLOYED', 'EJECTION',
                       'INJURY_CLASSIFICATION', 'DRIVER_ACTION', 'DRIVER_VISION', 'PHYSICAL_CONDITION',
                       'MAKE', 'MODEL', 'VEHICLE_DEFECT', 'VEHICLE_USE']

# Initialize the OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

# Apply the encoder to the categorical columns
df[categorical_columns] = ordinal_encoder.fit_transform(df[categorical_columns])

# Check the dataframe to ensure encoding
df.head()
# Out:
# <ipython-input-25-6a549f21a0f7>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical_columns] = ordinal_encoder.fit_transform(df[categorical_columns])
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#    PERSON_TYPE  SEX   AGE  SAFETY_EQUIPMENT  AIRBAG_DEPLOYED  EJECTION  \
# 1          0.0  2.0  35.0              16.0              4.0       4.0
# 2          3.0  0.0  14.0              13.0              5.0       0.0
# 3          0.0  0.0  27.0              13.0              5.0       0.0
# 4          0.0  0.0  43.0              13.0              5.0       0.0
# 5          0.0  0.0  26.0              13.0              5.0       0.0
#
#    INJURY_CLASSIFICATION  DRIVER_ACTION  DRIVER_VISION  PHYSICAL_CONDITION  \
# 1                    2.0           18.0           12.0                11.0
# 2                    2.0           18.0           12.0                11.0
# 3                    2.0           12.0            7.0                 8.0
# 4                    2.0           13.0            7.0                 8.0
# 5                    2.0           12.0            7.0                 8.0
#
#    MAKE  MODEL  VEHICLE_YEAR  VEHICLE_DEFECT  VEHICLE_USE  CRASH_YEAR  \
# 1  21.0    2.0          2014             0.0         17.0        2014
# 2   4.0   16.0          2011             6.0         17.0        2015
# 3   9.0   16.0          2015             6.0         17.0        2015
# 4   3.0   16.0          1990             6.0         17.0        2015
# 5  21.0    5.0          1997            14.0         24.0        2015
#
#    CRASH_MONTH
# 1           11
# 2           11
# 3           11
# 4           11
# 5            9

# %% [markdown]
# ## Data Splitting
#
# We will split the dataset into training and testing sets to prepare for model training and evaluation.

# %%
# Define features and target variable
features = df.drop(columns=['INJURY_CLASSIFICATION'])
target = df['INJURY_CLASSIFICATION']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# Display the shapes of the resulting datasets
print(f"Training Features Shape: {X_train.shape}")
print(f"Training Target Shape: {y_train.shape}")
print(f"Testing Features Shape: {X_test.shape}")
print(f"Testing Target Shape: {y_test.shape}")
# Out:
# Training Features Shape: (190444, 16)
# Training Target Shape: (190444,)
# Testing Features Shape: (81619, 16)
# Testing Target Shape: (81619,)

# %% [markdown]
# ## Modeling
#
# We will build and evaluate multiple classification models to predict the primary contributory cause of car accidents.

# %%
# Initialize the Logistic Regression model
logreg = LogisticRegression(max_iter=1000, random_state=42)

# Train the model
logreg.fit(X_train, y_train)

# Make predictions on the test set
y_pred = logreg.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1 Score: {f1:.2f}')

# Classification Report
print(classification_report(y_test, y_pred))
# Out:
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.92
# Precision: 0.86
# Recall: 0.92
# F1 Score: 0.89
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        30
#          1.0       0.00      0.00      0.00       559
#          2.0       0.92      1.00      0.96     75063
#          3.0       0.32      0.06      0.10      3715
#          4.0       0.00      0.00      0.00      2252
#
#     accuracy                           0.92     81619
#    macro avg       0.25      0.21      0.21     81619
# weighted avg       0.86      0.92      0.89     81619
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\HP\anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Define the Random Forest classifier
rf = RandomForestClassifier(random_state=42)

# Define the parameter grid for GridSearchCV
param_grid_rf = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Initialize GridSearchCV
grid_search_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=3, n_jobs=-1, verbose=2)

# Fit the model
grid_search_rf.fit(X_train, y_train)

# Print best parameters and best score
print(f"Best parameters for Random Forest: {grid_search_rf.best_params_}")
print(f"Best score for Random Forest: {grid_search_rf.best_score_}")

# Make predictions on the test set
y_pred_rf = grid_search_rf.best_estimator_.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
precision_rf = precision_score(y_test, y_pred_rf, average='weighted')
recall_rf = recall_score(y_test, y_pred_rf, average='weighted')
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

print(f'Random Forest - Accuracy: {accuracy_rf:.2f}')
print(f'Random Forest - Precision: {precision_rf:.2f}')
print(f'Random Forest - Recall: {recall_rf:.2f}')
print(f'Random Forest - F1 Score: {f1_rf:.2f}')

# Classification Report
print(classification_report(y_test, y_pred_rf))
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-c7713a4a7749> in <module>
#      15
#      16 # Fit the model
# ---> 17 grid_search_rf.fit(X_train, y_train)
#      18
#      19 # Print best parameters and best score
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1377     def _run_search(self, evaluate_candidates):
#    1378         """Search all candidates in param_grid"""
# -> 1379         evaluate_candidates(ParameterGrid(self.param_grid))
#    1380
#    1381
#
# ~\anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     820                     )
#     821
# --> 822                 out = parallel(
#     823                     delayed(_fit_and_score)(
#     824                         clone(base_estimator),
#
# ~\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# ~\anaconda3\envs\learn-env\lib\site-packages\joblib\parallel.py in retrieve(self)
#     938             try:
#     939                 if getattr(self._backend, 'supports_timeout', False):
# --> 940                     self._output.extend(job.get(timeout=self.timeout))
#     941                 else:
#     942                     self._output.extend(job.get())
#
# ~\anaconda3\envs\learn-env\lib\site-packages\joblib\_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~\anaconda3\envs\learn-env\lib\concurrent\futures\_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~\anaconda3\envs\learn-env\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
# Define the XGBoost classifier
xgb_model = xgb.XGBClassifier(random_state=42)

# Define the parameter grid for GridSearchCV
param_grid_xgb = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 6, 9],
    'learning_rate': [0.01, 0.1, 0.2],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Initialize GridSearchCV
grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb, cv=3, n_jobs=-1, verbose=2)

# Fit the model
grid_search_xgb.fit(X_train, y_train)

# Print best parameters and best score
print(f"Best parameters for XGBoost: {grid_search_xgb.best_params_}")
print(f"Best score for XGBoost: {grid_search_xgb.best_score_}")

# Make predictions on the test set
y_pred_xgb = grid_search_xgb.best_estimator_.predict(X_test)

# Evaluate the model
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
precision_xgb = precision_score(y_test, y_pred_xgb, average='weighted')
recall_xgb = recall_score(y_test, y_pred_xgb, average='weighted')
f1_xgb = f1_score(y_test, y_pred_xgb, average='weighted')

print(f'XGBoost - Accuracy: {accuracy_xgb:.2f}')
print(f'XGBoost - Precision: {precision_xgb:.2f}')
print(f'XGBoost - Recall: {recall_xgb:.2f}')
print(f'XGBoost - F1 Score: {f1_xgb:.2f}')

# Classification Report
print(classification_report(y_test, y_pred_xgb))
